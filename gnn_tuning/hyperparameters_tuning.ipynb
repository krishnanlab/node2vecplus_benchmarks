# %%
import pandas as pd

pd.set_option('display.max_colwidth', 200)
pd.set_option('display.width', 200)
df = pd.read_csv("../result/gene_classification_gnn_hp_tune.csv")

# %% [markdown]
# ### Define default and optimal parameters for tuning
#
# The tuning procedure contains two main stages
#
# - Stage 1: Tuning the GNN architecture (hidden dimension, number of layers, residual connection)
#     - Default training parameters: `lr = 1e-3`, `dropout = 0.1`, `weight_decay = 1e-5`
# - Stage 2: Tuning the training parameters (learning rate, dropout rate, weight decay)
#     - From step1, find the optimal GNN architectures that result in optimal validation
#     performance across different networks and datasets and fix these settings.

# %%
# Default training parameters
default_lr = "1e-03"
default_dropout = "0.1"
default_weight_decay = "1e-05"

# Optimal GCN architecture
optim_gcn_dim = "128"
optim_gcn_num_layers = "5"
optim_gcn_residual = "1"

# Optimal SAGE architecture
optim_sage_dim = "128"
optim_sage_num_layers = "5"
optim_sage_residual = "0"

# %%
def print_best(
    name,
    df,
    sep_width=100,
    top_k=10,
    sortby="Validation score",
):  
    df_top = (
        df
        .sort_values("Validation score", ascending=False)
        .head(top_k)
        .drop("RunID", axis=1)
        .reset_index(drop=True)
    )
    optim_settings = df_top.iloc[0]["Settings"]
    
    name_str = "_".join(name) if isinstance(name, tuple) else name
    print(name_str)
    print("=" * sep_width)
    print(f"Optimal settings: {optim_settings}")
    print(df_top)
    print("-" * sep_width)
    print()
    
    
def summarize(df):
    return (
        df
        .groupby(["Network", "Method", "Settings", "Task"], as_index=False)
        .median()  # Take the median across different runs
        .groupby(["Method", "Settings"], as_index=False)
        .median()  # Take the median across all networks and datsets
    )

# %% [markdown]
# ## GNN architecture tuning

# %%
# GNN architecture tuning results (fixed default training params)
default_settings = f"_lr={default_lr}_dropout={default_dropout}_weight-decay={default_weight_decay}"

df_architecture = df[df["Settings"].str.endswith(default_settings)].reset_index(drop=True).copy()
df_architecture["Settings"] = df_architecture["Settings"].str.replace(default_settings, "", regex=False)
df_architecture
# Out:
#        Training score  Validation score  Testing score          Task   Dataset              Network Method                         Settings  RunID
# 0            0.492660          0.850263       0.134878    GO:0006650      GOBP  HumanBaseTop-global   sage  dim=128_num-layers=4_residual=1      2
# 1            2.105350          0.501582       2.799723    GO:0006402      GOBP  HumanBaseTop-global   sage  dim=128_num-layers=4_residual=1      2
# 2            0.211608          0.638999       0.880677    GO:0010498      GOBP  HumanBaseTop-global   sage  dim=128_num-layers=4_residual=1      2
# 3            0.450761          0.338191       0.662027    GO:0006979      GOBP  HumanBaseTop-global   sage  dim=128_num-layers=4_residual=1      2
# 4            0.791923          0.699040       1.629855    GO:0097190      GOBP  HumanBaseTop-global   sage  dim=128_num-layers=4_residual=1      2
# ...               ...               ...            ...           ...       ...                  ...    ...                              ...    ...
# 62779        0.182574          0.189197       0.164578    DOID:12798  DisGeNet  HumanBaseTop-global    gcn   dim=16_num-layers=3_residual=0      3
# 62780        0.095949          0.631950       1.070099  DOID:0050889  DisGeNet  HumanBaseTop-global    gcn   dim=16_num-layers=3_residual=0      3
# 62781        0.320472          0.683901       1.090627      DOID:898  DisGeNet  HumanBaseTop-global    gcn   dim=16_num-layers=3_residual=0      3
# 62782        0.856812         -0.174031       0.504259    DOID:10126  DisGeNet  HumanBaseTop-global    gcn   dim=16_num-layers=3_residual=0      3
# 62783        0.602906          0.202507       0.000059     DOID:8469  DisGeNet  HumanBaseTop-global    gcn   dim=16_num-layers=3_residual=0      3
#
# [62784 rows x 9 columns]

# %%
# Optimal GNN architectures across all networks and tasks
for method, g in summarize(df_architecture).groupby("Method"):
    print_best(method, g.drop("Method", axis=1))
# Out:
# gcn
# ====================================================================================================
# Optimal settings: dim=128_num-layers=5_residual=1
#                           Settings  Training score  Validation score  Testing score
# 0  dim=128_num-layers=5_residual=1        0.927532          0.525010       0.582700
# 1  dim=128_num-layers=4_residual=1        0.884140          0.523634       0.595597
# 2   dim=64_num-layers=5_residual=1        0.750898          0.518476       0.569804
# 3   dim=64_num-layers=4_residual=1        0.762423          0.497992       0.562140
# 4  dim=128_num-layers=3_residual=1        0.751208          0.494621       0.546420
# 5  dim=128_num-layers=5_residual=0        0.688257          0.472200       0.485478
# 6   dim=32_num-layers=5_residual=1        0.640385          0.462043       0.476116
# 7  dim=128_num-layers=4_residual=0        0.697047          0.455927       0.465337
# 8   dim=64_num-layers=3_residual=1        0.702701          0.451847       0.572226
# 9   dim=32_num-layers=4_residual=1        0.616940          0.436825       0.502254
# ----------------------------------------------------------------------------------------------------
#
# sage
# ====================================================================================================
# Optimal settings: dim=128_num-layers=5_residual=0
#                           Settings  Training score  Validation score  Testing score
# 0  dim=128_num-layers=5_residual=0        2.097869          0.826212       0.752214
# 1   dim=64_num-layers=5_residual=0        1.544981          0.736173       0.756342
# 2  dim=128_num-layers=4_residual=0        1.916082          0.716348       0.721845
# 3   dim=64_num-layers=4_residual=0        1.342790          0.714873       0.601888
# 4  dim=128_num-layers=3_residual=0        1.455195          0.631075       0.590812
# 5   dim=32_num-layers=5_residual=0        1.021891          0.590589       0.633358
# 6   dim=32_num-layers=4_residual=0        0.879302          0.572869       0.560848
# 7   dim=64_num-layers=3_residual=0        0.906103          0.532632       0.486419
# 8  dim=128_num-layers=4_residual=1        0.672664          0.476599       0.493686
# 9   dim=16_num-layers=5_residual=0        0.604615          0.457403       0.444143
# ----------------------------------------------------------------------------------------------------

# %%
# Optimal GNN architecture specific to netowork and task
if True:  # switch to True to enable
    grouped = (
        df_architecture
        .groupby(["Network", "Method", "Dataset", "Task", "Settings"], as_index=False)
        .median()  # Take the median across different runs
        .groupby(["Network", "Method", "Dataset", "Settings"], as_index=False)
        .median()  # Take the median across all networks and datsets
        .groupby(["Method", "Network", "Dataset"])
    )

    for method, g in grouped:
        print_best(
            method,
            g.drop(["Method", "Network", "Dataset"], axis=1),
            top_k=10,
        )
# Out:
# gcn_HumanBase-global_DisGeNet
# ====================================================================================================
# Optimal settings: dim=16_num-layers=3_residual=1
#                           Settings  Training score  Validation score  Testing score
# 0   dim=16_num-layers=3_residual=1        0.414677          0.208876       0.234782
# 1   dim=16_num-layers=5_residual=1        0.308689          0.192509       0.213903
# 2   dim=32_num-layers=3_residual=1        0.335791          0.172183       0.211414
# 3   dim=64_num-layers=3_residual=1        0.268951          0.163877       0.274138
# 4  dim=128_num-layers=3_residual=1        0.031681          0.163488       0.261805
# 5   dim=64_num-layers=4_residual=1        0.279045          0.162812       0.250758
# 6   dim=16_num-layers=5_residual=0        0.413477          0.160257       0.272812
# 7   dim=32_num-layers=5_residual=0        0.422808          0.159230       0.272519
# 8  dim=128_num-layers=3_residual=0        0.412031          0.158366       0.273257
# 9   dim=16_num-layers=4_residual=0        0.423311          0.156767       0.249893
# ----------------------------------------------------------------------------------------------------
#
# gcn_HumanBase-global_GOBP
# ====================================================================================================
# Optimal settings: dim=128_num-layers=3_residual=1
#                           Settings  Training score  Validation score  Testing score
# 0  dim=128_num-layers=3_residual=1        0.701017          0.633355       0.568237
# 1  dim=128_num-layers=5_residual=1        0.750590          0.595829       0.617076
# 2   dim=64_num-layers=5_residual=1        0.605310          0.588237       0.612241
# 3  dim=128_num-layers=4_residual=1        0.747069          0.585153       0.643999
# 4   dim=64_num-layers=3_residual=1        0.684543          0.567835       0.637227
# 5   dim=64_num-layers=4_residual=1        0.534483          0.541359       0.588891
# 6   dim=32_num-layers=4_residual=1        0.481789          0.483837       0.468029
# 7  dim=128_num-layers=3_residual=0        0.462706          0.454108       0.425174
# 8   dim=32_num-layers=5_residual=1        0.416509          0.402085       0.364704
# 9   dim=64_num-layers=3_residual=0        0.404885          0.379220       0.399222
# ----------------------------------------------------------------------------------------------------
#
# gcn_HumanBaseTop-global_DisGeNet
# ====================================================================================================
# Optimal settings: dim=128_num-layers=5_residual=1
#                           Settings  Training score  Validation score  Testing score
# 0  dim=128_num-layers=5_residual=1        0.835678          0.472410       0.607944
# 1   dim=64_num-layers=3_residual=1        0.604039          0.451200       0.634047
# 2  dim=128_num-layers=4_residual=1        0.842273          0.439999       0.642751
# 3   dim=32_num-layers=5_residual=1        0.544065          0.433857       0.497969
# 4   dim=64_num-layers=5_residual=1        0.623725          0.423715       0.609854
# 5   dim=64_num-layers=3_residual=0        0.398468          0.418347       0.326407
# 6  dim=128_num-layers=5_residual=0        0.586148          0.414358       0.543408
# 7   dim=32_num-layers=3_residual=1        0.494309          0.410657       0.526763
# 8  dim=128_num-layers=3_residual=1        0.646179          0.409158       0.617980
# 9  dim=128_num-layers=4_residual=0        0.552252          0.407794       0.465898
# ----------------------------------------------------------------------------------------------------
#
# gcn_HumanBaseTop-global_GOBP
# ====================================================================================================
# Optimal settings: dim=128_num-layers=5_residual=1
#                           Settings  Training score  Validation score  Testing score
# 0  dim=128_num-layers=5_residual=1        1.371773          1.092518       0.647874
# 1   dim=64_num-layers=4_residual=1        1.193836          1.084611       0.657985
# 2   dim=64_num-layers=5_residual=1        1.150050          1.051615       0.538272
# 3  dim=128_num-layers=4_residual=1        1.325816          0.987387       0.640217
# 4   dim=32_num-layers=5_residual=1        1.078744          0.934381       0.539397
# 5  dim=128_num-layers=3_residual=1        1.267825          0.897640       0.591971
# 6   dim=32_num-layers=4_residual=1        1.025002          0.840576       0.704959
# 7   dim=32_num-layers=3_residual=1        0.905424          0.807147       0.679557
# 8   dim=16_num-layers=5_residual=1        0.691937          0.795322       0.475502
# 9   dim=64_num-layers=3_residual=1        0.992811          0.748490       0.695132
# ----------------------------------------------------------------------------------------------------
#
# gcn_STRING_DisGeNet
# ====================================================================================================
# Optimal settings: dim=128_num-layers=5_residual=0
#                           Settings  Training score  Validation score  Testing score
# 0  dim=128_num-layers=5_residual=0        0.907101          0.576557       0.650942
# 1  dim=128_num-layers=5_residual=1        1.174024          0.562232       0.633692
# 2   dim=64_num-layers=4_residual=1        1.028602          0.551605       0.616010
# 3  dim=128_num-layers=4_residual=1        1.121530          0.550425       0.612157
# 4   dim=64_num-layers=5_residual=0        0.862082          0.525384       0.647563
# 5   dim=64_num-layers=5_residual=1        1.068430          0.518357       0.633207
# 6   dim=32_num-layers=5_residual=0        0.808154          0.498358       0.647085
# 7   dim=32_num-layers=4_residual=0        0.774563          0.498319       0.662328
# 8  dim=128_num-layers=3_residual=1        0.968752          0.495146       0.564218
# 9   dim=64_num-layers=4_residual=0        0.836778          0.491186       0.641875
# ----------------------------------------------------------------------------------------------------
#
# gcn_STRING_GOBP
# ====================================================================================================
# Optimal settings: dim=128_num-layers=5_residual=1
#                           Settings  Training score  Validation score  Testing score
# 0  dim=128_num-layers=5_residual=1        2.666270          1.981219       1.974973
# 1  dim=128_num-layers=4_residual=1        2.239518          1.702364       1.663728
# 2   dim=64_num-layers=5_residual=1        2.023696          1.632736       1.648456
# 3  dim=128_num-layers=3_residual=1        1.804102          1.486904       1.228656
# 4   dim=32_num-layers=5_residual=1        1.454241          1.332276       0.877677
# 5   dim=64_num-layers=4_residual=1        1.678873          1.313368       1.137691
# 6   dim=32_num-layers=4_residual=1        1.549615          1.258351       0.927103
# 7  dim=128_num-layers=5_residual=0        1.762390          1.247005       1.064604
# 8   dim=64_num-layers=5_residual=0        1.446224          1.155457       1.010864
# 9   dim=64_num-layers=3_residual=1        1.695186          1.152385       0.996363
# ----------------------------------------------------------------------------------------------------
#
# sage_HumanBase-global_DisGeNet
# ====================================================================================================
# Optimal settings: dim=128_num-layers=5_residual=0
#                           Settings  Training score  Validation score  Testing score
# 0  dim=128_num-layers=5_residual=0        0.797699          0.408067       0.507743
# 1  dim=128_num-layers=4_residual=0        0.692089          0.345220       0.540424
# 2   dim=64_num-layers=5_residual=0        0.664203          0.285188       0.315061
# 3  dim=128_num-layers=3_residual=1        0.414808          0.276954       0.218940
# 4   dim=64_num-layers=3_residual=1        0.341217          0.244881       0.211954
# 5  dim=128_num-layers=4_residual=1        0.510739          0.235752       0.208814
# 6   dim=16_num-layers=4_residual=0        0.401660          0.231000       0.017944
# 7   dim=64_num-layers=4_residual=0        0.511357          0.224021       0.135352
# 8   dim=64_num-layers=5_residual=1        0.258001          0.221839       0.317995
# 9  dim=128_num-layers=3_residual=0        0.518746          0.218499       0.214866
# ----------------------------------------------------------------------------------------------------
#
# sage_HumanBase-global_GOBP
# ====================================================================================================
# Optimal settings: dim=128_num-layers=4_residual=0
#                           Settings  Training score  Validation score  Testing score
# 0  dim=128_num-layers=4_residual=0        1.344434          1.170748       0.768655
# 1  dim=128_num-layers=5_residual=0        1.880819          1.167339       1.151416
# 2   dim=64_num-layers=4_residual=0        1.198952          0.985827       0.687496
# 3  dim=128_num-layers=3_residual=0        1.084430          0.914809       0.675921
# 4  dim=128_num-layers=3_residual=1        0.639161          0.771833       0.473319
# 5   dim=64_num-layers=5_residual=0        1.449513          0.770674       0.871082
# 6   dim=64_num-layers=4_residual=1        0.600500          0.615642       0.337476
# 7  dim=128_num-layers=4_residual=1        0.673672          0.585260       0.406006
# 8  dim=128_num-layers=5_residual=1        0.721541          0.575637       0.491703
# 9   dim=32_num-layers=4_residual=0        0.738802          0.511372       0.438415
# ----------------------------------------------------------------------------------------------------
#
# sage_HumanBaseTop-global_DisGeNet
# ====================================================================================================
# Optimal settings: dim=128_num-layers=5_residual=0
#                           Settings  Training score  Validation score  Testing score
# 0  dim=128_num-layers=5_residual=0        1.962526          0.673839       0.538210
# 1   dim=64_num-layers=5_residual=0        1.311401          0.653604       0.594813
# 2   dim=64_num-layers=4_residual=0        1.056722          0.615122       0.590300
# 3  dim=128_num-layers=4_residual=0        1.746220          0.610364       0.519317
# 4  dim=128_num-layers=3_residual=0        1.028713          0.524983       0.568107
# 5   dim=32_num-layers=5_residual=0        0.807606          0.488332       0.495287
# 6   dim=64_num-layers=3_residual=0        0.754327          0.482781       0.601242
# 7   dim=32_num-layers=4_residual=0        0.619382          0.449337       0.475697
# 8  dim=128_num-layers=4_residual=1        0.398341          0.412300       0.484889
# 9   dim=16_num-layers=5_residual=0        0.456890          0.410008       0.505936
# ----------------------------------------------------------------------------------------------------
#
# sage_HumanBaseTop-global_GOBP
# ====================================================================================================
# Optimal settings: dim=32_num-layers=5_residual=0
#                           Settings  Training score  Validation score  Testing score
# 0   dim=32_num-layers=5_residual=0        1.468255          1.132807       0.668160
# 1  dim=128_num-layers=4_residual=0        2.367869          1.054409       0.860223
# 2   dim=32_num-layers=4_residual=0        1.577384          1.039978       0.897836
# 3   dim=64_num-layers=4_residual=0        1.516227          1.037001       0.791200
# 4   dim=32_num-layers=3_residual=0        1.179059          1.013742       0.714570
# 5   dim=64_num-layers=3_residual=0        1.214735          0.990353       0.714752
# 6  dim=128_num-layers=5_residual=0        1.747663          0.955447       0.685410
# 7   dim=64_num-layers=5_residual=0        1.754618          0.940650       0.798024
# 8   dim=16_num-layers=5_residual=0        0.832742          0.932819       0.577365
# 9  dim=128_num-layers=5_residual=1        1.241600          0.894447       0.511713
# ----------------------------------------------------------------------------------------------------
#
# sage_STRING_DisGeNet
# ====================================================================================================
# Optimal settings: dim=128_num-layers=5_residual=0
#                           Settings  Training score  Validation score  Testing score
# 0  dim=128_num-layers=5_residual=0        3.691479          1.001453       0.992465
# 1   dim=64_num-layers=5_residual=0        2.423144          0.902224       1.104158
# 2  dim=128_num-layers=4_residual=0        3.271112          0.877464       0.786364
# 3   dim=64_num-layers=4_residual=0        1.944679          0.857110       0.947199
# 4  dim=128_num-layers=3_residual=0        2.581588          0.813616       0.800486
# 5   dim=32_num-layers=5_residual=0        1.346582          0.812001       0.761203
# 6   dim=64_num-layers=3_residual=0        1.526296          0.708613       0.652233
# 7   dim=32_num-layers=4_residual=0        1.208366          0.681393       0.757880
# 8   dim=16_num-layers=5_residual=0        0.890773          0.512533       0.564238
# 9   dim=16_num-layers=4_residual=0        0.866689          0.511955       0.557908
# ----------------------------------------------------------------------------------------------------
#
# sage_STRING_GOBP
# ====================================================================================================
# Optimal settings: dim=64_num-layers=5_residual=0
#                           Settings  Training score  Validation score  Testing score
# 0   dim=64_num-layers=5_residual=0        4.292689          2.988469       2.006008
# 1  dim=128_num-layers=5_residual=0        4.973440          2.962777       1.960495
# 2  dim=128_num-layers=4_residual=0        4.797097          2.682262       1.957030
# 3   dim=32_num-layers=5_residual=0        3.258392          2.653023       2.185233
# 4   dim=64_num-layers=4_residual=0        4.147886          2.584002       1.691738
# 5   dim=32_num-layers=4_residual=0        3.022175          2.569344       1.704586
# 6  dim=128_num-layers=3_residual=0        4.336781          2.411761       1.634570
# 7   dim=64_num-layers=3_residual=0        3.534155          2.349929       1.428079
# 8   dim=16_num-layers=5_residual=0        2.463744          2.000415       1.579818
# 9   dim=32_num-layers=3_residual=0        2.139425          1.852675       1.240805
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Training parameters tuning

# %%
# GCN training parameter tuning results (fixed optimal architecture)
gcn_default_settings = f"dim={optim_gcn_dim}_num-layers={optim_gcn_num_layers}_residual={optim_gcn_residual}_"
sage_default_settings = f"dim={optim_sage_dim}_num-layers={optim_sage_num_layers}_residual={optim_sage_residual}_"

df_params_gcn = df[(df["Method"] == "gcn") & df["Settings"].str.startswith(gcn_default_settings)]
df_params_sage = df[(df["Method"] == "sage") & df["Settings"].str.startswith(sage_default_settings)]

df_params = pd.concat((df_params_gcn, df_params_sage)).reset_index(drop=True).copy()
df_params["Settings"] = (
    df_params["Settings"]
    .str.replace(gcn_default_settings, "", regex=False)
    .str.replace(sage_default_settings, "", regex=False)
)
df_params
# Out:
#         Training score  Validation score  Testing score          Task   Dataset              Network Method                                 Settings  RunID
# 0             0.441580          0.252272      -0.138474    GO:0006650      GOBP  HumanBaseTop-global    gcn  lr=1e-04_dropout=0.3_weight-decay=1e-05      2
# 1             1.112974          0.416632       1.227576    GO:0006402      GOBP  HumanBaseTop-global    gcn  lr=1e-04_dropout=0.3_weight-decay=1e-05      2
# 2             0.418688         -0.191268       0.612162    GO:0010498      GOBP  HumanBaseTop-global    gcn  lr=1e-04_dropout=0.3_weight-decay=1e-05      2
# 3             0.671823          0.539591       0.165061    GO:0006979      GOBP  HumanBaseTop-global    gcn  lr=1e-04_dropout=0.3_weight-decay=1e-05      2
# 4             0.039112          0.560334      -0.188806    GO:0097190      GOBP  HumanBaseTop-global    gcn  lr=1e-04_dropout=0.3_weight-decay=1e-05      2
# ...                ...               ...            ...           ...       ...                  ...    ...                                      ...    ...
# 125563        3.271680          1.041323      -0.005436    DOID:12798  DisGeNet  HumanBaseTop-global   sage  lr=1e-03_dropout=0.1_weight-decay=1e-05      3
# 125564        3.703126          1.555133      -0.354161  DOID:0050889  DisGeNet  HumanBaseTop-global   sage  lr=1e-03_dropout=0.1_weight-decay=1e-05      3
# 125565        3.701968          1.312620       1.575077      DOID:898  DisGeNet  HumanBaseTop-global   sage  lr=1e-03_dropout=0.1_weight-decay=1e-05      3
# 125566        4.556964          3.318602       0.981964    DOID:10126  DisGeNet  HumanBaseTop-global   sage  lr=1e-03_dropout=0.1_weight-decay=1e-05      3
# 125567        5.366595          5.698899       4.106480     DOID:8469  DisGeNet  HumanBaseTop-global   sage  lr=1e-03_dropout=0.1_weight-decay=1e-05      3
#
# [125568 rows x 9 columns]

# %%
# Optimal training parameters across all networks and tasks
for method, g in summarize(df_params).groupby("Method"):
    print_best(method, g.drop("Method", axis=1))
# Out:
# gcn
# ====================================================================================================
# Optimal settings: lr=1e-02_dropout=0.0_weight-decay=1e-07
#                                   Settings  Training score  Validation score  Testing score
# 0  lr=1e-02_dropout=0.0_weight-decay=1e-07        1.436468          0.666042       0.770542
# 1  lr=1e-02_dropout=0.1_weight-decay=1e-05        1.308662          0.661572       0.749599
# 2  lr=1e-02_dropout=0.3_weight-decay=1e-06        1.482503          0.653373       0.674426
# 3  lr=1e-02_dropout=0.1_weight-decay=1e-07        1.284914          0.648079       0.701588
# 4  lr=1e-02_dropout=0.0_weight-decay=1e-06        1.557433          0.646852       0.676283
# 5  lr=1e-02_dropout=0.1_weight-decay=1e-06        1.345290          0.645083       0.822977
# 6  lr=1e-02_dropout=0.3_weight-decay=1e-05        1.163370          0.623447       0.649762
# 7  lr=1e-02_dropout=0.3_weight-decay=1e-07        1.302024          0.611894       0.723543
# 8  lr=1e-02_dropout=0.0_weight-decay=1e-05        1.182503          0.596668       0.665247
# 9  lr=1e-03_dropout=0.3_weight-decay=1e-06        0.947362          0.566796       0.665691
# ----------------------------------------------------------------------------------------------------
#
# sage
# ====================================================================================================
# Optimal settings: lr=1e-03_dropout=0.1_weight-decay=1e-05
#                                   Settings  Training score  Validation score  Testing score
# 0  lr=1e-03_dropout=0.1_weight-decay=1e-05        2.097869          0.826212       0.752214
# 1  lr=1e-03_dropout=0.1_weight-decay=1e-06        1.988293          0.782382       0.716825
# 2  lr=1e-03_dropout=0.1_weight-decay=1e-04        2.395206          0.772966       0.761431
# 3  lr=1e-03_dropout=0.1_weight-decay=1e-07        1.879872          0.751475       0.747188
# 4  lr=1e-03_dropout=0.3_weight-decay=1e-04        1.774118          0.726314       0.736204
# 5  lr=1e-03_dropout=0.0_weight-decay=1e-07        2.148252          0.706402       0.671987
# 6  lr=1e-03_dropout=0.3_weight-decay=1e-06        1.318615          0.694447       0.681539
# 7  lr=1e-03_dropout=0.3_weight-decay=1e-05        1.284071          0.689632       0.638794
# 8  lr=1e-03_dropout=0.0_weight-decay=1e-05        2.045196          0.662362       0.702362
# 9  lr=1e-03_dropout=0.0_weight-decay=1e-04        2.282426          0.655567       0.706133
# ----------------------------------------------------------------------------------------------------

# %%
# Optimal training parameters specific to netowork and task
if True:  # switch to True to enable
    grouped = (
        df_params
        .groupby(["Network", "Method", "Dataset", "Task", "Settings"], as_index=False)
        .median()  # Take the median across different runs
        .groupby(["Network", "Method", "Dataset", "Settings"], as_index=False)
        .median()  # Take the median across all networks and datsets
        .groupby(["Method", "Network", "Dataset"])
    )

    for method, g in grouped:
        print_best(
            method,
            g.drop(["Method", "Network", "Dataset"], axis=1),
            top_k=10,
        )
# Out:
# gcn_HumanBase-global_DisGeNet
# ====================================================================================================
# Optimal settings: lr=1e-02_dropout=0.1_weight-decay=1e-06
#                                   Settings  Training score  Validation score  Testing score
# 0  lr=1e-02_dropout=0.1_weight-decay=1e-06        0.724978          0.262921       0.420333
# 1  lr=1e-02_dropout=0.1_weight-decay=1e-07        0.704256          0.248826       0.436120
# 2  lr=1e-02_dropout=0.0_weight-decay=1e-07        0.701434          0.247944       0.435271
# 3  lr=1e-02_dropout=0.0_weight-decay=1e-06        0.669217          0.233586       0.397931
# 4  lr=1e-01_dropout=0.1_weight-decay=1e-07        0.463783          0.210342       0.110865
# 5  lr=1e-02_dropout=0.1_weight-decay=1e-05        0.638662          0.208608       0.372844
# 6  lr=1e-02_dropout=0.3_weight-decay=1e-07        0.653443          0.199543       0.398563
# 7  lr=1e-01_dropout=0.1_weight-decay=1e-05        0.409466          0.196484       0.243173
# 8  lr=1e-02_dropout=0.0_weight-decay=1e-05        0.612657          0.187597       0.354433
# 9  lr=1e-02_dropout=0.1_weight-decay=1e-04        0.452495          0.185856       0.191115
# ----------------------------------------------------------------------------------------------------
#
# gcn_HumanBase-global_GOBP
# ====================================================================================================
# Optimal settings: lr=1e-03_dropout=0.3_weight-decay=1e-07
#                                   Settings  Training score  Validation score  Testing score
# 0  lr=1e-03_dropout=0.3_weight-decay=1e-07        0.720785          0.681710       0.611651
# 1  lr=1e-02_dropout=0.1_weight-decay=1e-07        0.855980          0.680703       0.596371
# 2  lr=1e-03_dropout=0.0_weight-decay=1e-05        0.671619          0.669481       0.616288
# 3  lr=1e-02_dropout=0.1_weight-decay=1e-05        0.738412          0.647738       0.517499
# 4  lr=1e-02_dropout=0.3_weight-decay=1e-05        0.777938          0.635104       0.591826
# 7  lr=1e-02_dropout=0.1_weight-decay=1e-05        0.458007          0.289598       0.246194
# 8  lr=1e-04_dropout=0.0_weight-decay=1e-04        0.925506          0.287336       0.524754
# 9  lr=1e-02_dropout=0.0_weight-decay=1e-07        0.868616          0.286213       0.424157
# ----------------------------------------------------------------------------------------------------
#
# sage_HumanBase-global_GOBP
# ====================================================================================================
# Optimal settings: lr=1e-03_dropout=0.1_weight-decay=1e-07
#                                   Settings  Training score  Validation score  Testing score
# 0  lr=1e-03_dropout=0.1_weight-decay=1e-07        1.599134          1.284369       1.160303
# 1  lr=1e-03_dropout=0.0_weight-decay=1e-05        1.961649          1.242750       1.150917
# 2  lr=1e-03_dropout=0.0_weight-decay=1e-07        2.260332          1.220595       1.195669
# 3  lr=1e-03_dropout=0.1_weight-decay=1e-05        1.880819          1.167339       1.151416
# 4  lr=1e-03_dropout=0.0_weight-decay=1e-04        2.049272          1.030879       1.036063
# 5  lr=1e-03_dropout=0.0_weight-decay=1e-06        2.109811          0.993687       0.971030
# 6  lr=1e-04_dropout=0.0_weight-decay=1e-06        1.899383          0.990621       1.023701
# 7  lr=1e-03_dropout=0.1_weight-decay=1e-06        1.739246          0.990459       1.125752
# 8  lr=1e-03_dropout=0.1_weight-decay=1e-04        1.864524          0.987798       0.919877
# 9  lr=1e-03_dropout=0.3_weight-decay=1e-06        1.266048          0.933381       0.944020
# ----------------------------------------------------------------------------------------------------
#
# sage_HumanBaseTop-global_DisGeNet
# ====================================================================================================
# Optimal settings: lr=1e-03_dropout=0.1_weight-decay=1e-05
#                                   Settings  Training score  Validation score  Testing score
# 0  lr=1e-03_dropout=0.1_weight-decay=1e-05        1.962526          0.673839       0.538210
# 1  lr=1e-03_dropout=0.3_weight-decay=1e-04        1.542080          0.662871       0.636490
# 2  lr=1e-03_dropout=0.1_weight-decay=1e-04        2.309462          0.657556       0.479230
# 3  lr=1e-03_dropout=0.1_weight-decay=1e-06        1.658807          0.623393       0.542918
# 4  lr=1e-02_dropout=0.1_weight-decay=1e-05        1.145241          0.602249       0.602361
# 5  lr=1e-03_dropout=0.1_weight-decay=1e-07        1.594166          0.599406       0.581087
# 6  lr=1e-02_dropout=0.1_weight-decay=1e-07        0.854727          0.595989       0.594294
# 7  lr=1e-03_dropout=0.3_weight-decay=1e-06        0.938149          0.582801       0.496353
# 8  lr=1e-03_dropout=0.3_weight-decay=1e-05        1.156484          0.579065       0.584685
# 9  lr=1e-03_dropout=0.0_weight-decay=1e-07        1.807656          0.567170       0.478676
# ----------------------------------------------------------------------------------------------------
#
# sage_HumanBaseTop-global_GOBP
# ====================================================================================================
# Optimal settings: lr=1e-02_dropout=0.0_weight-decay=1e-07
#                                   Settings  Training score  Validation score  Testing score
# 0  lr=1e-02_dropout=0.0_weight-decay=1e-07        1.570570          1.181498       0.792147
# 1  lr=1e-02_dropout=0.1_weight-decay=1e-05        1.305036          1.157835       0.679647
# 2  lr=1e-02_dropout=0.0_weight-decay=1e-05        1.964869          1.089746       0.787756
